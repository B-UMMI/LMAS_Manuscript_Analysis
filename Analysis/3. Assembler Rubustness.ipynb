# %% [markdown]
# # Assembler rubustness - contigs

# %% [markdown]
# ## Imports

# %%
import sys
from plotly.offline import plot
import glob
import fnmatch
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import json
import pandas as pd
from itertools import groupby
import csv
import numpy as np

# %% [markdown]
# ## Global variables

# %%
ASSEMBLER_PROCESS_LIST = ["ABYSS", "BCALM2", "GATBMINIAPIPELINE", "MINIA", "MEGAHIT", "METASPADES", "UNICYCLER", "SPADES",
                          "SKESA", "VELVETOPTIMIZER", "IDBA", "METAHIPMER2"]
PROCESS_TO_NAME = {"ABYSS": "ABySS",
                   "BCALM2": "BCALM2", 
                   "GATBMINIAPIPELINE": "GATBMiniaPipeline",
                   "MINIA": "MINIA",
                   "MEGAHIT": "MEGAHIT",
                   "METAHIPMER2": "MetaHipMer2",
                   "METASPADES": "metaSPAdes", 
                   "UNICYCLER": "Unicycler", 
                   "SPADES": "SPAdes",
                    "SKESA": "SKESA",
                   "VELVETOPTIMIZER": "VelvetOptimizer",
                   "IDBA": "IDBA-UD"}
log_distributed = ['LHS', 'LNN', 'ERR2935805']
even_distribution = ['EMS', 'LNN', 'ERR2984773']

# %% [markdown]
# ## Load Data

# %%
contig_size_files = glob.glob('../Results/*/*/results/*/stats/*_df.csv')

df_list = []
for f in contig_size_files:
    run = f.split('/')[-5]
    df = pd.read_csv(f)
    df['run'] = run
    df_list.append(df)

contig_size_df = pd.concat(df_list)
contig_size_df['distribution'] = np.where(contig_size_df['Sample'].isin(log_distributed), 'Log', 'Even')

contig_size_df
# Out:
#     Unnamed: 0 index      Sample          Assembler    Contig Contig Len  \
# 0            0     0         LNN            MEGAHIT    k141_1       1297
# 1            1     1         LNN            MEGAHIT  k141_945       1057
# 2            2     2         LNN            MEGAHIT  k141_477       1599
# 3            3     3         LNN            MEGAHIT   k141_45       4626
# 4            4     4         LNN            MEGAHIT   k141_49       1160
# ..         ...   ...         ...                ...       ...        ...
# 758        758   758  ERR2984773  GATBMiniaPipeline      5392     215478
# 759        759   759  ERR2984773  GATBMiniaPipeline      5393     283087
# 760        760   760  ERR2984773  GATBMiniaPipeline      5394     263420
# 761        761   761  ERR2984773  GATBMiniaPipeline      5395     193260
# 762        762   762  ERR2984773  GATBMiniaPipeline      5396     549434
#
#                      Mapped #N   run distribution
# 0         Bacillus_subtilis  0  run3          Log
# 1    Pseudomonas_aeruginosa  0  run3          Log
# 2    Pseudomonas_aeruginosa  0  run3          Log
# 3    Listeria_monocytogenes  0  run3          Log
# 4          Escherichia_coli  0  run3          Log
# ..                      ... ..   ...          ...
# 758  Pseudomonas_aeruginosa  0  run2         Even
# 759     Salmonella_enterica  0  run2         Even
# 760       Bacillus_subtilis  0  run2         Even
# 761   Enterococcus_faecalis  0  run2         Even
# 762   Enterococcus_faecalis  0  run2         Even
#
# [283640 rows x 10 columns]

# %% [markdown]
# ## Filter unique contigs

# %%
df_all_runs = contig_size_df.groupby('Contig Len').filter(lambda x: len(x) == 3)
df_all_runs
# Out:
#     Unnamed: 0 index      Sample          Assembler     Contig Contig Len  \
# 3            3     3         LNN            MEGAHIT    k141_45       4626
# 8            8     8         LNN            MEGAHIT    k141_80      30016
# 11          11    11         LNN            MEGAHIT  k141_1392      83817
# 14          14    14         LNN            MEGAHIT  k141_1165     104155
# 20          20    20         LNN            MEGAHIT    k141_82     122571
# ..         ...   ...         ...                ...        ...        ...
# 758        758   758  ERR2984773  GATBMiniaPipeline       5392     215478
# 759        759   759  ERR2984773  GATBMiniaPipeline       5393     283087
# 760        760   760  ERR2984773  GATBMiniaPipeline       5394     263420
# 761        761   761  ERR2984773  GATBMiniaPipeline       5395     193260
# 762        762   762  ERR2984773  GATBMiniaPipeline       5396     549434
#
#                      Mapped #N   run distribution
# 3    Listeria_monocytogenes  0  run3          Log
# 8         Bacillus_subtilis  0  run3          Log
# 11        Bacillus_subtilis  0  run3          Log
# 14        Bacillus_subtilis  0  run3          Log
# 20        Bacillus_subtilis  0  run3          Log
# ..                      ... ..   ...          ...
# 758  Pseudomonas_aeruginosa  0  run2         Even
# 759     Salmonella_enterica  0  run2         Even
# 760       Bacillus_subtilis  0  run2         Even
# 761   Enterococcus_faecalis  0  run2         Even
# 762   Enterococcus_faecalis  0  run2         Even
#
# [28485 rows x 10 columns]

# %% [markdown]
# ### Contigs present in 2 runs

# %%
df_2runs = contig_size_df.groupby('Contig Len').filter(lambda x: len(x) == 2)
df_2runs
# Out:
#     Unnamed: 0 index      Sample        Assembler  \
# 10          10    10         LNN  VelvetOptimiser
# 11          11    11         LNN  VelvetOptimiser
# 17          17    17         LNN  VelvetOptimiser
# 18          18    18         LNN  VelvetOptimiser
# 26          26    26         LNN  VelvetOptimiser
# ..         ...   ...         ...              ...
# 391        391   391  ERR2984773            MINIA
# 590        590   590  ERR2984773            MINIA
# 636        636   636  ERR2984773            MINIA
# 826        826   826  ERR2984773            MINIA
# 847        847   847  ERR2984773            MINIA
#
#                                    Contig Contig Len                   Mapped  \
# 10   NODE_106_length_295194_cov_15.789176     295224        Bacillus_subtilis
# 11   NODE_106_length_295194_cov_15.789176     295224        Bacillus_subtilis
# 17   NODE_165_length_169344_cov_15.595870     169374        Bacillus_subtilis
# 18   NODE_165_length_169344_cov_15.595870     169374        Bacillus_subtilis
# 26    NODE_438_length_98582_cov_15.263172      98612        Bacillus_subtilis
# ..                                    ...        ...                      ...
# 391                                   458      13742  Lactobacillus_fermentum
# 590                                   746      20387   Pseudomonas_aeruginosa
# 636                                   805      24773    Staphylococcus_aureus
# 826                                  1043       5137         Escherichia_coli
# 847                                  1070       7832   Pseudomonas_aeruginosa
#
#       #N   run distribution
# 10   228  run3          Log
# 11   228  run3          Log
# 17   176  run3          Log
# 18   176  run3          Log
# 26   523  run3          Log
# ..   ...   ...          ...
# 391    0  run2         Even
# 590    0  run2         Even
# 636    0  run2         Even
# 826    0  run2         Even
# 847    0  run2         Even
#
# [1300 rows x 10 columns]

# %% [markdown]
# ### Contigs present in only 1 run

# %%
df_1run = contig_size_df.groupby('Contig Len').filter(lambda x: len(x) == 1)
df_1run
# Out:
#      Unnamed: 0 index      Sample          Assembler  \
# 886         886   886         LNN              ABySS
# 1188       1188  1188         LNN              ABySS
# 1             1     1         LNN    VelvetOptimiser
# 2             2     2         LNN    VelvetOptimiser
# 3             3     3         LNN    VelvetOptimiser
# ...         ...   ...         ...                ...
# 710         710   710  ERR2984773              MINIA
# 863         863   863  ERR2984773              MINIA
# 1090       1090  1090  ERR2984773              MINIA
# 1445       1445  1445  ERR2984773              MINIA
# 492         492   492  ERR2984773  GATBMiniaPipeline
#
#                                      Contig Contig Len  \
# 886                                   93243     256771
# 1188                                  93556     730778
# 1        NODE_15_length_23166_cov_16.622982      23196
# 2     NODE_17_length_210216_cov_2883.458252     210246
# 3       NODE_18_length_104398_cov_15.914673     104428
# ...                                     ...        ...
# 710                                     892      28107
# 863                                    1090      12227
# 1090                                   1376      19444
# 1445                                   1990      11589
# 492                                    3506      32818
#
#                       Mapped   #N   run distribution
# 886   Listeria_monocytogenes    0  run3          Log
# 1188  Listeria_monocytogenes    0  run3          Log
# 1          Bacillus_subtilis    0  run3          Log
# 2     Listeria_monocytogenes    0  run3          Log
# 3          Bacillus_subtilis  106  run3          Log
# ...                      ...  ...   ...          ...
# 710    Enterococcus_faecalis    0  run2         Even
# 863   Pseudomonas_aeruginosa    0  run2         Even
# 1090   Enterococcus_faecalis    0  run2         Even
# 1445  Pseudomonas_aeruginosa    0  run2         Even
# 492                 Unmapped    0  run2         Even
#
# [684 rows x 10 columns]

# %% [markdown]
# ## Plot data

# %%
#Just the different contigs
fig_contigs = go.Figure()
for assembler in sorted(contig_size_df['Assembler'].unique(), key=lambda v: v.upper(), reverse=True):
    showlegend = True if assembler == "MINIA" else False
    #all
    contigs_df_all=df_all_runs[df_all_runs['Assembler'] == assembler]
    if not contigs_df_all.empty:
        coord_list = list(contigs_df_all['Contig Len'])
        fig_contigs.add_trace(go.Box(x=coord_list,  marker_color="gray",name=assembler,showlegend=False))

    #n=1
    contigs_df= df_1run[df_1run['Assembler'] == assembler]
    if not contigs_df.empty:
        coord_list = list(contigs_df['Contig Len'])
        fig_contigs.add_trace(go.Scattergl(x=coord_list,
                                               y=[assembler]*len(coord_list),
                                               mode='markers',
                                               opacity=0.5,
                                               marker_symbol='line-ns',
                                               marker=dict(color='lightseagreen', size=12,
                                                           line=dict(width=5,
                                                                     color='#930001')),
                                               name="Present in 1 run",
                                               showlegend=showlegend))
    #n=2
    contigs_df_2= df_2runs[df_2runs['Assembler'] == assembler]
    if not contigs_df_2.empty:
        coord_list = list(contigs_df_2['Contig Len'])
        fig_contigs.add_trace(go.Scattergl(x=coord_list,
                                               y=[assembler]*len(coord_list),
                                               mode='markers',
                                               opacity=0.5,
                                               marker_symbol='line-ns',
                                               marker=dict(color='orange', size=12,
                                                           line=dict(width=5,
                                                                     color='#009392')),
                                               name="Present in 2 runs",
                                               showlegend=showlegend))

fig_contigs.update_layout(plot_bgcolor='rgb(255,255,255)', title="Inconsistent contigs per assembler over 3 LMAS runs")
fig_contigs.update_xaxes(showline=True, linewidth=1, linecolor='#DCDCDC', gridcolor='#DCDCDC', title="Contig Size in Basepairs")
fig_contigs.show()
plot(fig_contigs,auto_open=False, filename="Plots/Contig Size/Unique contigs in 3 runs")
# Out:
# <div>                            <div id="dd094f7d-d74b-4298-869b-2c65ff36327f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dd094f7d-d74b-4298-869b-2c65ff36327f")) {                    Plotly.newPlot(                        "dd094f7d-d74b-4298-869b-2c65ff36327f",                        [{"marker":{"color":"gray"},"name":"VelvetOptimiser","showlegend":false,"type":"box","x":[9518,6685,8824,7459,4017,4070,4070,4017,8506,6035,5741,5052,23087,243430,6185,15303,7267,6988,26448,21108,22558,19599,19738,11157,67228,7936,8616,19339,12212,11784,18388,38046,171085,50935,15513,118774,118626,134740,176112,23183,117484,264293,256470,190027,294525,204459,93019,56019,259036,56498,76784,68452,90026,277556,465312,374756,187170,55585,39382,50679,39581,7969,94039,57420,72433,76580,56210,63196,23145,73759,186032,15301,34750,23086,19891,10602,12531,7347,6146,6364,8357,10681,8470,9950,27962,26388,40453,77267,23348,29176,23707,53380,15620,31248,22739,22961,22231,28966,18716,38555,30446,15673,11171,8684,59371,50851,30503,25642,49845,19337,8615,11842,20916,12166,10959,11767,46341,12089,12197,11091,14668,23928,27945,9730,12627,5995,6911,7323,60793,69013,82979,17541,26548,61375,14501,24332,35817,17201,28178,29715,7332,32375,55771,26742,338923,22563,23895,118630,264811,16535,47741,56553,176018,210643,238828,196736,189959,257611,119788,425263,187217,77016,173591,204461,294492,177187,191195,15306,23340,27455,63225,32653,50659,23417,48640,10709,20476,15979,12487,30317,58518,6456,7805,16355,15662,10889,20142,18525,5790,4070,3895,5676,7592,5052,7179,3967,3215,4801,5052,6685,4017,3215,3215,23087,243430,6185,15303,7267,6988,26448,21108,22558,19599,19738,11157,67228,7936,8616,19339,12212,11784,18388,38046,171085,50935,15513,118774,118626,134740,176112,23183,117484,264293,256470,190027,294525,204459,93019,56019,259036,56498,76784,68452,90026,277556,465312,374756,187170,55585,39382,50679,39581,7969,94039,57420,72433,76580,56210,63196,23145,73759,186032,15301,34750,23086,19891,10602,12531,7347,6146,6364,8357,10681,8470,9950,27962,26388,40453,77267,23348,29176,23707,53380,15620,31248,22739,22961,22231,28966,18716,38555,30446,15673,11171,8684,59371,50851,30503,25642,49845,19337,8615,11842,20916,12166,10959,11767,46341,12089,12197,11091,14668,23928,27945,9730,12627,5995,6911,7323,60793,69013,82979,17541,26548,61375,14501,24332,35817,17201,28178,29715,7332,32375,55771,26742,338923,22563,23895,118630,264811,16535,47741,56553,176018,210643,238828,196736,189959,257611,119788,425263,187217,77016,173591,204461,294492,177187,191195,15306,23340,27455,63225,32653,50659,23417,48640,10709,20476,15979,12487,30317,58518,6456,7805,16355,15662,10889,20142,18525,5790,23087,243430,6185,15303,7267,6988,26448,21108,22558,19599,19738,11157,67228,7936,8616,19339,12212,11784,18388,38046,171085,50935,15513,118774,118626,134740,176112,23183,117484,264293,256470,190027,294525,204459,93019,56019,259036,56498,76784,68452,90026,277556,465312,374756,187170,55585,39382,50679,39581,7969,94039,57420,72433,76580,56210,63196,23145,73759,186032,15301,34750,23086,19891,10602,12531,7347,6146,6364,8357,10681,8470,9950,27962,26388,40453,77267,23348,29176,23707,53380,15620,31248,22739,22961,22231,28966,18716,38555,30446,15673,11171,8684,59371,50851,30503,25642,49845,19337,8615,11842,20916,12166,10959,11767,46341,12089,12197,11091,14668,23928,27945,9730,12627,5995,6911,7323,60793,69013,82979,17541,26548,61375,14501,24332,35817,17201,28178,29715,7332,32375,55771,26742,338923,22563,23895,118630,264811,16535,47741,56553,176018,210643,238828,196736,189959,257611,119788,425263,187217,77016,173591,204461,294492,177187,191195,15306,23340,27455,63225,32653,50659,23417,48640,10709,20476,15979,12487,30317,58518,6456,7805,16355,15662,10889,20142,18525,5790]},{"marker":{"color":"lig ...
# /home/ines/anaconda3/envs/LMAS/lib/python3.8/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Plots/Contig Size/Unique contigs in 3 runs` didn't end with .html. Adding .html to the end of your file.
# 'Plots/Contig Size/Unique contigs in 3 runs.html'

# %%
((df_2runs[df_2runs['Assembler']=='GATBMiniaPipeline'].size + df_1run[df_1run['Assembler']=='GATBMiniaPipeline'].size)/contig_size_df[contig_size_df['Assembler']=='GATBMiniaPipeline'].size)*100
# Out:
# 0.3221873911529084

# %%
((df_2runs[df_2runs['Assembler']=='IDBA-UD'].size + df_1run[df_1run['Assembler']=='IDBA-UD'].size)/contig_size_df[contig_size_df['Assembler']=='IDBA-UD'].size)*100
# Out:
# 0.08339651250947687

# %%
((df_2runs[df_2runs['Assembler']=='MINIA'].size + df_1run[df_1run['Assembler']=='MINIA'].size)/contig_size_df[contig_size_df['Assembler']=='MINIA'].size)*100
# Out:
# 0.14367507987905562

# %%
((df_2runs[df_2runs['Assembler']=='VelvetOptimiser'].size + df_1run[df_1run['Assembler']=='VelvetOptimiser'].size)/contig_size_df[contig_size_df['Assembler']=='VelvetOptimiser'].size)*100
# Out:
# 1.6409236411101098

# %%
((df_2runs[df_2runs['Assembler']=='ABySS'].size + df_1run[df_1run['Assembler']=='ABySS'].size)/contig_size_df[contig_size_df['Assembler']=='ABySS'].size)*100
# Out:
# 9.22695035460993

# %%
for assembler in contig_size_df['Assembler'].unique():
    print(assembler, contig_size_df[contig_size_df['Assembler']==assembler].size)
# Out:
# MEGAHIT 182190
# ABySS 141000
# MINIA 466330
# metaSPAdes 184470
# SPAdes 307710
# Unicycler 51240
# BCALM2 333870
# IDBA-UD 263800
# SKESA 235530
# GATBMiniaPipeline 114840
# VelvetOptimiser 321770
# MetaHipMer2 233650

# %%
for assembler in contig_size_df['Assembler'].unique():
    print(assembler, df_2runs[df_2runs['Assembler']==assembler].size)
# Out:
# MEGAHIT 20
# ABySS 10900
# MINIA 410
# metaSPAdes 0
# SPAdes 0
# Unicycler 0
# BCALM2 0
# IDBA-UD 160
# SKESA 0
# GATBMiniaPipeline 250
# VelvetOptimiser 1100
# MetaHipMer2 160

# %%
for assembler in contig_size_df['Assembler'].unique():
    print(assembler, df_1run[df_1run['Assembler']==assembler].size)
# Out:
# MEGAHIT 10
# ABySS 2110
# MINIA 260
# metaSPAdes 0
# SPAdes 0
# Unicycler 0
# BCALM2 0
# IDBA-UD 60
# SKESA 0
# GATBMiniaPipeline 120
# VelvetOptimiser 4180
# MetaHipMer2 100

# %%
# COMMENTS - HOW TO ACCOUNT FOR FAILED RUNS
