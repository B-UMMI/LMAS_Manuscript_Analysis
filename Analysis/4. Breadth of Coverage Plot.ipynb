# %% [markdown]
# # Assembler rubustness - Breadth of Coverage

# %% [markdown]
# ## Imports

# %%
import sys
from plotly.offline import plot
import glob
import fnmatch
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import json
import pandas as pd
from itertools import groupby
import csv
import numpy as np
from statistics import mean

# %% [markdown]
# ## Global variables

# %%
ASSEMBLER_PROCESS_LIST = ["ABYSS", "BCALM2", "GATBMINIAPIPELINE", "METAHIPMER2", "MINIA", "MEGAHIT", "METASPADES", "UNICYCLER", "SPADES",
                          "SKESA", "VELVETOPTIMIZER", "IDBA"]
PROCESS_TO_NAME = {"ABYSS": "ABySS",
                   "BCALM2": "BCALM2", 
                   "GATBMINIAPIPELINE": "GATBMiniaPipeline",
                   "METAHIPMER2": "MetaHipMer2",
                   "MINIA": "MINIA",
                   "MEGAHIT": "MEGAHIT", 
                   "METASPADES": "metaSPAdes", 
                   "UNICYCLER": "Unicycler", 
                   "SPADES": "SPAdes",
                    "SKESA": "SKESA",
                   "VELVETOPTIMIZER": "VelvetOptimizer",
                   "IDBA": "IDBA-UD"}

log_distributed = ['LHS', 'LNN', 'ERR2935805']
even_distribution = ['EMS', 'LNN', 'ERR2984773']

COLOURS = ['#5876c8', '#58AEC8', '#009392', '#39B185', '#9CCB86', '#E9E29C', '#EEB479', '#E88471', '#CF597E', '#a54765', '#a42a2a', '#835221']

# %% [markdown]
# ## Load data

# %%
_files = glob.glob('../Results/*/*/results/*/stats/*_breadth_of_coverage_contigs.csv')

df_list = []
for f in _files:
    run = f.split('/')[-5]
    sample = f.split('/')[-3]
    assembler = f.split('/')[-1].split('_')[1]
    df = pd.read_csv(f)
    df['run'] = run
    df['Sample'] = sample
    df['Assembler'] = assembler
    df_list.append(df)

df = pd.concat(df_list)
df['distribution'] = np.where(df['Sample'].isin(log_distributed), 'Log', 'Even')
df
# Out:
#     Unnamed: 0                       Reference  Breadth of Coverage  Contigs  \
# 0            0               Bacillus_subtilis             0.976159      205
# 1            1           Enterococcus_faecalis             0.000000        0
# 2            2        Escherichia_coli_plasmid             0.000000        0
# 3            3                Escherichia_coli             0.000000        0
# 4            4         Lactobacillus_fermentum             0.001233        2
# ..         ...                             ...                  ...      ...
# 7            7             Salmonella_enterica             0.977899      145
# 8            8           Staphylococcus_aureus             0.983494       49
# 9            9  Staphylococcus_aureus_plasmid1             0.979012        2
# 10          10  Staphylococcus_aureus_plasmid2             1.000000        1
# 11          11  Staphylococcus_aureus_plasmid3             1.000000        1
#
#      run      Sample   Assembler distribution
# 0   run3         LNN      BCALM2          Log
# 1   run3         LNN      BCALM2          Log
# 2   run3         LNN      BCALM2          Log
# 3   run3         LNN      BCALM2          Log
# 4   run3         LNN      BCALM2          Log
# ..   ...         ...         ...          ...
# 7   run2  ERR2984773  metaSPAdes         Even
# 8   run2  ERR2984773  metaSPAdes         Even
# 9   run2  ERR2984773  metaSPAdes         Even
# 10  run2  ERR2984773  metaSPAdes         Even
# 11  run2  ERR2984773  metaSPAdes         Even
#
# [2472 rows x 8 columns]

# %%
len(df["Reference"].unique())
# Out:
# 12

# %% [markdown]
# ## Plot data

# %% [markdown]
# ### Per sample

# %%
for sample in sorted(df['Sample'].unique(), key=lambda v: v.upper(), reverse=True):
    print('-' + sample)
    fig=make_subplots(rows=3, cols=4, subplot_titles=sorted(df['Reference'].unique(), key=lambda v: v.upper(), reverse=False),
                     shared_yaxes=True, shared_xaxes=True, x_title="Contigs", y_title="Breadth of Coverage")
    row=1
    col=1
    for reference in sorted(df['Reference'].unique(), key=lambda v: v.upper(), reverse=False):
        print('--' + reference)
        i=0
        print(row, col)
        for assembler in sorted(df['Assembler'].unique(), key=lambda v: v.upper(), reverse=True):
            print('---' + assembler)
            showlegend=True if col==1 and row==1 else False
            contigs = list(df['Contigs'][(df['Assembler'] == assembler) & (df['Reference'] == reference) & (df['Sample'] == sample)])
            boc = list(df['Breadth of Coverage'][(df['Assembler'] == assembler) & (df['Reference'] == reference) & (df['Sample'] == sample)])
            if contigs: #list not empty
                fig.add_trace(go.Scatter(x=[mean(contigs)],
                                         y=[mean(boc)],
                                         error_y=dict(type='data', # value of error bar given in data coordinates
                                                      symmetric=False,
                                                      array=[max(boc)-mean(boc)],
                                                      arrayminus=[mean(boc)-min(boc)],
                                                      visible=True),
                                         error_x=dict(type='data', # value of error bar given in data coordinates
                                                      symmetric=False,
                                                      array=[max(contigs)-mean(contigs)],
                                                      arrayminus=[mean(contigs)-min(contigs)],
                                                      visible=True),
                                         name=assembler, marker=dict(color=COLOURS[i], size=12), showlegend=showlegend),
                              col=col, row=row)
            i+=1
        if col == 4:
            col = 1
            row += 1
        else:
            col += 1
    fig.update_layout(plot_bgcolor='rgb(255,255,255)', title="{} Genome Coverage variation".format(sample))
    fig.update_xaxes(showline=True, linewidth=1, linecolor='#DCDCDC', gridcolor='#DCDCDC', rangemode='tozero')
    fig.update_yaxes(showline=True, linewidth=1, linecolor='#DCDCDC', gridcolor='#DCDCDC', range=[0, 1])
    for i in fig['layout']['annotations']:
        i['font']['size'] = 12
    fig.update_layout(legend=dict(
        orientation="h",
        y=-0.1,
        x=0
    ))
    fig.show()
    plot(fig, filename='Plots/Genome Fragmentation/{}.html'.format(sample), auto_open=False)
# Out:
# -LNN
# --Bacillus_subtilis
# 1 1
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Enterococcus_faecalis
# 1 2
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Escherichia_coli
# 1 3
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Escherichia_coli_plasmid
# 1 4
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Lactobacillus_fermentum
# 2 1
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Listeria_monocytogenes
# 2 2
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Pseudomonas_aeruginosa
# 2 3
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Salmonella_enterica
# 2 4
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Staphylococcus_aureus
# 3 1
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Staphylococcus_aureus_plasmid1
# 3 2
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Staphylococcus_aureus_plasmid2
# 3 3
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Staphylococcus_aureus_plasmid3
# 3 4
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# <div>                            <div id="f39d69ae-9a27-461d-a4ed-e0a70d9ee446" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f39d69ae-9a27-461d-a4ed-e0a70d9ee446")) {                    Plotly.newPlot(                        "f39d69ae-9a27-461d-a4ed-e0a70d9ee446",                        [{"error_x":{"array":[792.6666666666667],"arrayminus":[398.3333333333333],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.03833565226948832],"arrayminus":[0.0755711178458719],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#5876c8","size":12},"name":"VelvetOptimiser","showlegend":true,"type":"scatter","x":[426.3333333333333],"xaxis":"x","y":[0.9428581009639013],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#58AEC8","size":12},"name":"Unicycler","showlegend":true,"type":"scatter","x":[23],"xaxis":"x","y":[0.5029536465713896],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#009392","size":12},"name":"SPAdes","showlegend":true,"type":"scatter","x":[65],"xaxis":"x","y":[0.9812113028301568],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#39B185","size":12},"name":"SKESA","showlegend":true,"type":"scatter","x":[0],"xaxis":"x","y":[0.0],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#9CCB86","size":12},"name":"MINIA","showlegend":true,"type":"scatter","x":[208],"xaxis":"x","y":[0.9765349532352682],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#E9E29C","size":12},"name":"metaSPAdes","showlegend":true,"type":"scatter","x":[50],"xaxis":"x","y":[0.9833140411357604],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#E88471","size":12},"name":"MEGAHIT","showlegend":true,"type":"scatter","x":[57],"xaxis":"x","y":[0.9849577709738072],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#CF597E","size":12},"name":"IDBA-UD","showlegend":true,"type":"scatter","x":[102],"xaxis":"x","y":[0.9814928379106884],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#a54765","size":12},"name":"GATBMiniaPipeline","showlegend":true,"type":"scatter","x":[94],"xaxis":"x","y":[0.9821458806523604],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#a42a2a","size":12},"name":"BCALM2","showlegend":true,"type":"scatter","x":[205],"xaxis":"x","y":[0.976158996380581],"yaxis":"y"},{"error_x":{"array":[0.33333333333325754],"arrayminus":[0.6666666666667425],"s ...
# -LHS
# --Bacillus_subtilis
# 1 1
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Enterococcus_faecalis
# 1 2
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Escherichia_coli
# 1 3
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Escherichia_coli_plasmid
# 1 4
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Lactobacillus_fermentum
# 2 1
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Listeria_monocytogenes
# 2 2
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Pseudomonas_aeruginosa
# 2 3
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Salmonella_enterica
# 2 4
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Staphylococcus_aureus
# 3 1
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Staphylococcus_aureus_plasmid1
# 3 2
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Staphylococcus_aureus_plasmid2
# 3 3
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Staphylococcus_aureus_plasmid3
# 3 4
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# <div>                            <div id="9564e6f3-0667-4624-b9c5-4d57f2ed9494" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9564e6f3-0667-4624-b9c5-4d57f2ed9494")) {                    Plotly.newPlot(                        "9564e6f3-0667-4624-b9c5-4d57f2ed9494",                        [{"error_x":{"array":[260.66666666666663],"arrayminus":[326.33333333333337],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.21680466993946046],"arrayminus":[0.3964328673132663],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#5876c8","size":12},"name":"VelvetOptimiser","showlegend":true,"type":"scatter","x":[993.3333333333334],"xaxis":"x","y":[0.6168370172243937],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#58AEC8","size":12},"name":"Unicycler","showlegend":true,"type":"scatter","x":[179],"xaxis":"x","y":[0.9425394068780084],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#009392","size":12},"name":"SPAdes","showlegend":true,"type":"scatter","x":[116],"xaxis":"x","y":[0.9799089250081012],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#39B185","size":12},"name":"SKESA","showlegend":true,"type":"scatter","x":[0],"xaxis":"x","y":[0.0],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#9CCB86","size":12},"name":"MINIA","showlegend":true,"type":"scatter","x":[783],"xaxis":"x","y":[0.9446683459900532],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#E9E29C","size":12},"name":"metaSPAdes","showlegend":true,"type":"scatter","x":[110],"xaxis":"x","y":[0.9817553403299374],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#E88471","size":12},"name":"MEGAHIT","showlegend":true,"type":"scatter","x":[223],"xaxis":"x","y":[0.9812340431527282],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#CF597E","size":12},"name":"IDBA-UD","showlegend":true,"type":"scatter","x":[418],"xaxis":"x","y":[0.9703893810603268],"yaxis":"y"},{"error_x":{"array":[0.33333333333337123],"arrayminus":[0.6666666666666288],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[2.9661290310567523e-06],"arrayminus":[1.4830645155283761e-06],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#a54765","size":12},"name":"GATBMiniaPipeline","showlegend":true,"type":"scatter","x":[603.6666666666666],"xaxis":"x","y":[0.9595649875163046],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#a42a2a","size":12},"name":"BCALM2","showlegend":true,"type":"scatter","x":[11],"xaxis":"x","y":[0.002957972176226 ...
# -ERR2984773
# --Bacillus_subtilis
# 1 1
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Enterococcus_faecalis
# 1 2
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Escherichia_coli
# 1 3
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Escherichia_coli_plasmid
# 1 4
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Lactobacillus_fermentum
# 2 1
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Listeria_monocytogenes
# 2 2
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Pseudomonas_aeruginosa
# 2 3
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Salmonella_enterica
# 2 4
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Staphylococcus_aureus
# 3 1
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Staphylococcus_aureus_plasmid1
# 3 2
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Staphylococcus_aureus_plasmid2
# 3 3
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Staphylococcus_aureus_plasmid3
# 3 4
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# <div>                            <div id="12f4a139-2134-4f72-a3f5-d560b2d287ed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("12f4a139-2134-4f72-a3f5-d560b2d287ed")) {                    Plotly.newPlot(                        "12f4a139-2134-4f72-a3f5-d560b2d287ed",                        [{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#5876c8","size":12},"name":"VelvetOptimiser","showlegend":true,"type":"scatter","x":[0],"xaxis":"x","y":[0.0],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#58AEC8","size":12},"name":"Unicycler","showlegend":true,"type":"scatter","x":[18],"xaxis":"x","y":[0.982525050813498],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#009392","size":12},"name":"SPAdes","showlegend":true,"type":"scatter","x":[33],"xaxis":"x","y":[0.982951184684294],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#39B185","size":12},"name":"SKESA","showlegend":true,"type":"scatter","x":[34],"xaxis":"x","y":[0.98144587420103],"yaxis":"y"},{"error_x":{"array":[0.3333333333333428],"arrayminus":[0.6666666666666572],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[7.497715050708287e-06],"arrayminus":[7.580107523663671e-06],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#9CCB86","size":12},"name":"MINIA","showlegend":true,"type":"scatter","x":[169.66666666666666],"xaxis":"x","y":[0.9761309829397321],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#E9E29C","size":12},"name":"metaSPAdes","showlegend":true,"type":"scatter","x":[51],"xaxis":"x","y":[0.98267706492634],"yaxis":"y"},{"error_x":{"array":[3.666666666666657],"arrayminus":[4.333333333333343],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0010449013436646878],"arrayminus":[0.00138633575212916],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#EEB479","size":12},"name":"MetaHipMer2","showlegend":true,"type":"scatter","x":[176.33333333333334],"xaxis":"x","y":[0.052191429683256144],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#E88471","size":12},"name":"MEGAHIT","showlegend":true,"type":"scatter","x":[31],"xaxis":"x","y":[0.9861187633120488],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#CF597E","size":12},"name":"IDBA-UD","showlegend":true,"type":"scatter","x":[184],"xaxis":"x","y":[0.983004575006853],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#a54765","size":12},"name":"GATBMiniaPipeline","showlegend":true,"type":"scatter","x":[30],"xaxis":"x","y":[0.9842629552482812],"y ...
# -ERR2935805
# --Bacillus_subtilis
# 1 1
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Enterococcus_faecalis
# 1 2
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Escherichia_coli
# 1 3
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Escherichia_coli_plasmid
# 1 4
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Lactobacillus_fermentum
# 2 1
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Listeria_monocytogenes
# 2 2
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Pseudomonas_aeruginosa
# 2 3
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Salmonella_enterica
# 2 4
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Staphylococcus_aureus
# 3 1
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Staphylococcus_aureus_plasmid1
# 3 2
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Staphylococcus_aureus_plasmid2
# 3 3
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Staphylococcus_aureus_plasmid3
# 3 4
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# <div>                            <div id="da432af4-d6ac-49cf-9e18-b899e0ed9068" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("da432af4-d6ac-49cf-9e18-b899e0ed9068")) {                    Plotly.newPlot(                        "da432af4-d6ac-49cf-9e18-b899e0ed9068",                        [{"error_x":{"array":[10],"arrayminus":[5],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.002750919891363876],"arrayminus":[0.0013754599456819382],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#5876c8","size":12},"name":"VelvetOptimiser","showlegend":true,"type":"scatter","x":[11],"xaxis":"x","y":[0.0030120216385704215],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#58AEC8","size":12},"name":"Unicycler","showlegend":true,"type":"scatter","x":[0],"xaxis":"x","y":[0.0],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#009392","size":12},"name":"SPAdes","showlegend":true,"type":"scatter","x":[37],"xaxis":"x","y":[0.9824096189587058],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#39B185","size":12},"name":"SKESA","showlegend":true,"type":"scatter","x":[0],"xaxis":"x","y":[0.0],"yaxis":"y"},{"error_x":{"array":[1.6666666666666856],"arrayminus":[1.3333333333333144],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.00014056155908315215],"arrayminus":[7.028077954163159e-05],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#9CCB86","size":12},"name":"MINIA","showlegend":true,"type":"scatter","x":[278.3333333333333],"xaxis":"x","y":[0.9742894287738081],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#E9E29C","size":12},"name":"metaSPAdes","showlegend":true,"type":"scatter","x":[107],"xaxis":"x","y":[0.9818789290395649],"yaxis":"y"},{"error_x":{"array":[3],"arrayminus":[3],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0005095974460310737],"arrayminus":[0.0008157678760152276],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#EEB479","size":12},"name":"MetaHipMer2","showlegend":true,"type":"scatter","x":[1412],"xaxis":"x","y":[0.8687169868808937],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#E88471","size":12},"name":"MEGAHIT","showlegend":true,"type":"scatter","x":[27],"xaxis":"x","y":[0.9843252439579334],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[1.40067204246197e-06],"arrayminus":[2.80134408492394e-06],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#CF597E","size":12},"name":"IDBA-UD","showlegend":true,"type":"scatter","x":[74],"xaxis":"x","y":[0.9821167961093615],"yaxis":"y"},{"error_x":{"array":[0.6666666666666572],"arrayminus":[0.3333333333333428],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[3.295698923766466e-07],"arrayminus":[1.6478494624383444e-07],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#a54765","size":12},"name":"GATBMiniaPipe ...
# -ENN
# --Bacillus_subtilis
# 1 1
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Enterococcus_faecalis
# 1 2
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Escherichia_coli
# 1 3
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Escherichia_coli_plasmid
# 1 4
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Lactobacillus_fermentum
# 2 1
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Listeria_monocytogenes
# 2 2
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Pseudomonas_aeruginosa
# 2 3
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Salmonella_enterica
# 2 4
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Staphylococcus_aureus
# 3 1
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Staphylococcus_aureus_plasmid1
# 3 2
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Staphylococcus_aureus_plasmid2
# 3 3
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Staphylococcus_aureus_plasmid3
# 3 4
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# <div>                            <div id="c662aa3b-f33c-4e00-863a-ebff862550a1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c662aa3b-f33c-4e00-863a-ebff862550a1")) {                    Plotly.newPlot(                        "c662aa3b-f33c-4e00-863a-ebff862550a1",                        [{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#5876c8","size":12},"name":"VelvetOptimiser","showlegend":true,"type":"scatter","x":[109],"xaxis":"x","y":[0.9773353137188164],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#58AEC8","size":12},"name":"Unicycler","showlegend":true,"type":"scatter","x":[22],"xaxis":"x","y":[0.982219786700718],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#009392","size":12},"name":"SPAdes","showlegend":true,"type":"scatter","x":[22],"xaxis":"x","y":[0.984425597990151],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#39B185","size":12},"name":"SKESA","showlegend":true,"type":"scatter","x":[30],"xaxis":"x","y":[0.9806675125077954],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#9CCB86","size":12},"name":"MINIA","showlegend":true,"type":"scatter","x":[116],"xaxis":"x","y":[0.9768449137190142],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#E9E29C","size":12},"name":"metaSPAdes","showlegend":true,"type":"scatter","x":[18],"xaxis":"x","y":[0.9857267399251102],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#EEB479","size":12},"name":"MetaHipMer2","showlegend":true,"type":"scatter","x":[27],"xaxis":"x","y":[0.9826357862973244],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[1.5901747305480107e-05],"arrayminus":[1.8950268809714288e-05],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#E88471","size":12},"name":"MEGAHIT","showlegend":true,"type":"scatter","x":[27],"xaxis":"x","y":[0.9860427974518645],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#CF597E","size":12},"name":"IDBA-UD","showlegend":true,"type":"scatter","x":[38],"xaxis":"x","y":[0.9828495947649799],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#a54765","size":12},"name":"GATBMiniaPipeline","showlegend":true,"type":"scatter","x":[28],"xaxis":"x","y":[0.9836615725872332],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y": ...
# -EMS
# --Bacillus_subtilis
# 1 1
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Enterococcus_faecalis
# 1 2
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Escherichia_coli
# 1 3
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Escherichia_coli_plasmid
# 1 4
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Lactobacillus_fermentum
# 2 1
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Listeria_monocytogenes
# 2 2
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Pseudomonas_aeruginosa
# 2 3
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Salmonella_enterica
# 2 4
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Staphylococcus_aureus
# 3 1
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Staphylococcus_aureus_plasmid1
# 3 2
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Staphylococcus_aureus_plasmid2
# 3 3
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Staphylococcus_aureus_plasmid3
# 3 4
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# <div>                            <div id="8fe2dd76-866a-48c6-a5b9-424b89c8cc70" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8fe2dd76-866a-48c6-a5b9-424b89c8cc70")) {                    Plotly.newPlot(                        "8fe2dd76-866a-48c6-a5b9-424b89c8cc70",                        [{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#5876c8","size":12},"name":"VelvetOptimiser","showlegend":true,"type":"scatter","x":[113],"xaxis":"x","y":[0.977186760089844],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#58AEC8","size":12},"name":"Unicycler","showlegend":true,"type":"scatter","x":[20],"xaxis":"x","y":[0.9827551729908244],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#009392","size":12},"name":"SPAdes","showlegend":true,"type":"scatter","x":[22],"xaxis":"x","y":[0.9840948746031876],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#39B185","size":12},"name":"SKESA","showlegend":true,"type":"scatter","x":[26],"xaxis":"x","y":[0.9816483125074],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#9CCB86","size":12},"name":"MINIA","showlegend":true,"type":"scatter","x":[117],"xaxis":"x","y":[0.9771417737995396],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#E9E29C","size":12},"name":"metaSPAdes","showlegend":true,"type":"scatter","x":[23],"xaxis":"x","y":[0.9840563149257836],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#EEB479","size":12},"name":"MetaHipMer2","showlegend":true,"type":"scatter","x":[28],"xaxis":"x","y":[0.9828730766198092],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#E88471","size":12},"name":"MEGAHIT","showlegend":true,"type":"scatter","x":[27],"xaxis":"x","y":[0.9853656137155784],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#CF597E","size":12},"name":"IDBA-UD","showlegend":true,"type":"scatter","x":[34],"xaxis":"x","y":[0.9832334612970832],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#a54765","size":12},"name":"GATBMiniaPipeline","showlegend":true,"type":"scatter","x":[27],"xaxis":"x","y":[0.984780297586782],"yaxis":"y"},{"error_x":{"array":[0],"arrayminus":[0],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0],"arrayminus":[0.0],"symmet ...

# %% [markdown]
# ### All Samples - Even only

# %%
fig=make_subplots(rows=3, cols=4, subplot_titles=[x.replace('_', ' ') for x in sorted(df['Reference'].unique(), key=lambda v: v.upper(), reverse=False)],
                 shared_yaxes=True, shared_xaxes=True, x_title="Contigs", y_title="Breadth of Coverage")
row=1
col=1
for reference in sorted(df['Reference'].unique(), key=lambda v: v.upper(), reverse=False):
    print('--' + reference)
    i=0
    print(row, col)
    for assembler in sorted(df['Assembler'].unique(), key=lambda v: v.upper(), reverse=True):
        print('---' + assembler)
        showlegend=True if col==1 and row==1 else False
        
        contigs = list(df['Contigs'][(df['Assembler'] == assembler) & (df['Reference'] == reference) & (df['distribution'] == 'Even')])
        boc = list(df['Breadth of Coverage'][(df['Assembler'] == assembler) & (df['Reference'] == reference) & (df['distribution'] == 'Even')])
        if contigs: #list not empty
            fig.add_trace(go.Scatter(x=[mean(contigs)],
                                     y=[mean(boc)],
                                     error_y=dict(type='data', # value of error bar given in data coordinates
                                                  symmetric=False,
                                                  array=[max(boc)-mean(boc)],
                                                  arrayminus=[mean(boc)-min(boc)],
                                                  visible=True),
                                     error_x=dict(type='data', # value of error bar given in data coordinates
                                                  symmetric=False,
                                                  array=[max(contigs)-mean(contigs)],
                                                  arrayminus=[mean(contigs)-min(contigs)],
                                                  visible=True),
                                     name=assembler, marker=dict(color=COLOURS[i], opacity=0.6, size=12), showlegend=showlegend),
                          col=col, row=row)
        i+=1
    if col == 4:
        col = 1
        row += 1
    else:
        col += 1
        
fig.update_layout(plot_bgcolor='rgb(255,255,255)', title="Genome fragmentation variation")
fig.update_xaxes(showline=True, linewidth=1, linecolor='#DCDCDC', gridcolor='#DCDCDC', rangemode='tozero')
fig.update_yaxes(showline=True, linewidth=1, linecolor='#DCDCDC', gridcolor='#DCDCDC', range=[0, 1])
for i in fig['layout']['annotations']:
    i['font']['size'] = 12
fig.update_layout(legend=dict(
    orientation="h",
    y=-0.1,
    x=0
))
fig.show()
plot(fig, filename='Plots/Genome Fragmentation/Figure 5 - Genome fragmentation for even samples.html', auto_open=False)
# Out:
# --Bacillus_subtilis
# 1 1
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Enterococcus_faecalis
# 1 2
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Escherichia_coli
# 1 3
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Escherichia_coli_plasmid
# 1 4
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Lactobacillus_fermentum
# 2 1
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Listeria_monocytogenes
# 2 2
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Pseudomonas_aeruginosa
# 2 3
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Salmonella_enterica
# 2 4
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Staphylococcus_aureus
# 3 1
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Staphylococcus_aureus_plasmid1
# 3 2
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Staphylococcus_aureus_plasmid2
# 3 3
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# --Staphylococcus_aureus_plasmid3
# 3 4
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# <div>                            <div id="8f00cc4f-1d2f-4c72-a3ac-a536f97d2970" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8f00cc4f-1d2f-4c72-a3ac-a536f97d2970")) {                    Plotly.newPlot(                        "8f00cc4f-1d2f-4c72-a3ac-a536f97d2970",                        [{"error_x":{"array":[39],"arrayminus":[74],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.32582795578259627],"arrayminus":[0.6515073579362202],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#5876c8","opacity":0.6,"size":12},"name":"VelvetOptimiser","showlegend":true,"type":"scatter","x":[74],"xaxis":"x","y":[0.6515073579362202],"yaxis":"y"},{"error_x":{"array":[2],"arrayminus":[2],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.00025516948914428017],"arrayminus":[0.00028021680096212975],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#58AEC8","opacity":0.6,"size":12},"name":"Unicycler","showlegend":true,"type":"scatter","x":[20],"xaxis":"x","y":[0.9825000035016801],"yaxis":"y"},{"error_x":{"array":[7.333333333333332],"arrayminus":[3.666666666666668],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0006017122309400769],"arrayminus":[0.0008727010749168818],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#009392","opacity":0.6,"size":12},"name":"SPAdes","showlegend":true,"type":"scatter","x":[25.666666666666668],"xaxis":"x","y":[0.9838238857592109],"yaxis":"y"},{"error_x":{"array":[4],"arrayminus":[4],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0003944127686582588],"arrayminus":[0.0005863872309463947],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#39B185","opacity":0.6,"size":12},"name":"SKESA","showlegend":true,"type":"scatter","x":[30],"xaxis":"x","y":[0.9812538997387418],"yaxis":"y"},{"error_x":{"array":[35.77777777777777],"arrayminus":[18.22222222222223],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0004358836467776017],"arrayminus":[0.0005824873205535486],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#9CCB86","opacity":0.6,"size":12},"name":"MINIA","showlegend":true,"type":"scatter","x":[134.22222222222223],"xaxis":"x","y":[0.976705890152762],"yaxis":"y"},{"error_x":{"array":[20.333333333333332],"arrayminus":[12.666666666666668],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0015733666660322498],"arrayminus":[0.00147630833273793],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#E9E29C","opacity":0.6,"size":12},"name":"metaSPAdes","showlegend":true,"type":"scatter","x":[30.666666666666668],"xaxis":"x","y":[0.9841533732590779],"yaxis":"y"},{"error_x":{"array":[102.88888888888889],"arrayminus":[50.111111111111114],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.3103063124196792],"arrayminus":[0.621761670269003],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#EEB479","opacity":0.6,"size":12},"name":"MetaHipMer2","showlegend":true,"type":"scatter","x":[77.11111111111111],"xaxis":"x","y":[0.67256676420013],"yaxis":"y"},{"error_x":{"array":[2.666666666666668],"arrayminus":[1.3333333333333321],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.0002763718188849573],"arrayminus":[0.0004767777775854798],"symmetric":false,"type":"data","visible":true},"marker":{"color":"#E88471","opacity":0.6,"size":12},"name":"MEGAHIT","showlegend":true,"type":"scatter","x":[28.333333333333332],"xaxis":"x","y":[0.9858423914931639],"yaxis":"y"},{"error_x":{"array":[98.66666666666667],"arrayminus":[51.33333333333333],"symmetric":false,"type":"data","visible":true},"error_y":{"array":[0.00020425094077780592],"arrayminus": ...
# 'Plots/Genome Fragmentation/Figure 5 - Genome fragmentation for even samples.html'
