# %% [markdown]
# # LMAS PLS Metrics Analysis

# %%
import sys
from plotly.offline import plot
import glob
import fnmatch
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import json
import pandas as pd
from itertools import groupby
import csv
import numpy as np

# %%
PLS_files = glob.glob('../Results/*/*/results/*/stats/*phred.csv')
PLS_df = pd.DataFrame(columns=['run', 'Sample', 'Assembler','Reference','Contig','Contig Length','Phred Quality Score'])

for PLS_file in PLS_files:
    report_file_name = PLS_file.split('/')[-1]
    stats_run = PLS_file.split('/')[3]
    sample_name = report_file_name.split('_')[0]
    print('Processing {0} data from {1}...'.format(report_file_name, stats_run))
    
    with open(PLS_file) as tsvfile:
        tsvreader = csv.reader(tsvfile, delimiter=",")
        next(tsvreader, None)
        for row in tsvreader:
            PLS_df = PLS_df.append({'run': stats_run,
                                    'Assembler': row[1],
                                    'Sample': sample_name,
                                    'Reference': row[2],
                                    'Contig': row[3],
                                    'Contig Length': row[4],
                                    'Phred Quality Score': row[5]}, ignore_index=True)
display(PLS_df)
# Out:
# Processing LNN_MINIA_phred.csv data from run2...
# Processing LNN_ABySS_phred.csv data from run2...
# Processing LNN_Unicycler_phred.csv data from run2...
# Processing LNN_GATBMiniaPipeline_phred.csv data from run2...
# Processing LNN_SPAdes_phred.csv data from run2...
# Processing LNN_VelvetOptimiser_phred.csv data from run2...
# Processing LNN_SKESA_phred.csv data from run2...
# Processing LNN_BCALM2_phred.csv data from run2...
# Processing LNN_MEGAHIT_phred.csv data from run2...
# Processing LNN_metaSPAdes_phred.csv data from run2...
# Processing LNN_IDBA-UD_phred.csv data from run2...
# Processing ERR2935805_GATBMiniaPipeline_phred.csv data from run2...
# Processing ERR2935805_MEGAHIT_phred.csv data from run2...
# Processing ERR2935805_metaSPAdes_phred.csv data from run2...
# Processing ERR2935805_MINIA_phred.csv data from run2...
# Processing ERR2935805_Unicycler_phred.csv data from run2...
# Processing ERR2935805_BCALM2_phred.csv data from run2...
# Processing ERR2935805_IDBA-UD_phred.csv data from run2...
# Processing ERR2935805_ABySS_phred.csv data from run2...
# Processing ERR2935805_MetaHipMer2_phred.csv data from run2...
# Processing ERR2935805_SPAdes_phred.csv data from run2...
# Processing ERR2935805_VelvetOptimiser_phred.csv data from run2...
# Processing ERR2935805_SKESA_phred.csv data from run2...
# Processing LHS_VelvetOptimiser_phred.csv data from run2...
# Processing LHS_GATBMiniaPipeline_phred.csv data from run2...
# Processing LHS_SKESA_phred.csv data from run2...
# Processing LHS_MINIA_phred.csv data from run2...
# Processing LHS_BCALM2_phred.csv data from run2...
# Processing LHS_Unicycler_phred.csv data from run2...
# Processing LHS_SPAdes_phred.csv data from run2...
# Processing LHS_metaSPAdes_phred.csv data from run2...
# Processing LHS_MEGAHIT_phred.csv data from run2...
# Processing LHS_IDBA-UD_phred.csv data from run2...
# Processing ENN_Unicycler_phred.csv data from run1...
# Processing ENN_MEGAHIT_phred.csv data from run1...
# Processing ENN_ABySS_phred.csv data from run1...
# Processing ENN_MINIA_phred.csv data from run1...
# Processing ENN_GATBMiniaPipeline_phred.csv data from run1...
# Processing ENN_BCALM2_phred.csv data from run1...
# Processing ENN_VelvetOptimiser_phred.csv data from run1...
# Processing ENN_metaSPAdes_phred.csv data from run1...
# Processing ENN_SPAdes_phred.csv data from run1...
# Processing ENN_MetaHipMer2_phred.csv data from run1...
# Processing ENN_IDBA-UD_phred.csv data from run1...
# Processing ENN_SKESA_phred.csv data from run1...
# Processing EMS_VelvetOptimiser_phred.csv data from run1...
# Processing EMS_SKESA_phred.csv data from run1...
# Processing EMS_IDBA-UD_phred.csv data from run1...
# Processing EMS_BCALM2_phred.csv data from run1...
# Processing EMS_Unicycler_phred.csv data from run1...
# Processing EMS_ABySS_phred.csv data from run1...
# Processing EMS_MINIA_phred.csv data from run1...
# Processing EMS_metaSPAdes_phred.csv data from run1...
# Processing EMS_MetaHipMer2_phred.csv data from run1...
# Processing EMS_SPAdes_phred.csv data from run1...
# Processing EMS_MEGAHIT_phred.csv data from run1...
# Processing EMS_GATBMiniaPipeline_phred.csv data from run1...
# Processing LNN_MINIA_phred.csv data from run1...
# Processing LNN_ABySS_phred.csv data from run1...
# Processing LNN_Unicycler_phred.csv data from run1...
# Processing LNN_GATBMiniaPipeline_phred.csv data from run1...
# Processing LNN_SPAdes_phred.csv data from run1...
# Processing LNN_VelvetOptimiser_phred.csv data from run1...
# Processing LNN_SKESA_phred.csv data from run1...
# Processing LNN_BCALM2_phred.csv data from run1...
# Processing LNN_MEGAHIT_phred.csv data from run1...
# Processing LNN_metaSPAdes_phred.csv data from run1...
# Processing LNN_IDBA-UD_phred.csv data from run1...
# Processing ERR2935805_GATBMiniaPipeline_phred.csv data from run1...
# Processing ERR2935805_MEGAHIT_phred.csv data from run1...
# Processing ERR2935805_metaSPAdes_phred.csv data from run1...
# Processing ERR2935805_MINIA_phred.csv data from run1...
# Processing ERR2935805_Unicycler_phred.csv data from run1...
# Processing ERR2935805_BCALM2_phred.csv data from run1...
# Processing ERR2935805_IDBA-UD_phred.csv data from run1...
# Processing ERR2935805_ABySS_phred.csv data from run1...
# Processing ERR2935805_MetaHipMer2_phred.csv data from run1...
# Processing ERR2935805_SPAdes_phred.csv data from run1...
# Processing ERR2935805_VelvetOptimiser_phred.csv data from run1...
# Processing ERR2935805_SKESA_phred.csv data from run1...
# Processing LHS_VelvetOptimiser_phred.csv data from run1...
# Processing LHS_GATBMiniaPipeline_phred.csv data from run1...
# Processing LHS_SKESA_phred.csv data from run1...
# Processing LHS_MINIA_phred.csv data from run1...
# Processing LHS_BCALM2_phred.csv data from run1...
# Processing LHS_Unicycler_phred.csv data from run1...
# Processing LHS_SPAdes_phred.csv data from run1...
# Processing LHS_metaSPAdes_phred.csv data from run1...
# Processing LHS_MEGAHIT_phred.csv data from run1...
# Processing LHS_IDBA-UD_phred.csv data from run1...
# Processing ERR2984773_SKESA_phred.csv data from run1...
# Processing ERR2984773_MetaHipMer2_phred.csv data from run1...
# Processing ERR2984773_Unicycler_phred.csv data from run1...
# Processing ERR2984773_BCALM2_phred.csv data from run1...
# Processing ERR2984773_VelvetOptimiser_phred.csv data from run1...
# Processing ERR2984773_SPAdes_phred.csv data from run1...
# Processing ERR2984773_IDBA-UD_phred.csv data from run1...
# Processing ERR2984773_ABySS_phred.csv data from run1...
# Processing ERR2984773_metaSPAdes_phred.csv data from run1...
# Processing ERR2984773_MEGAHIT_phred.csv data from run1...
# Processing ERR2984773_MINIA_phred.csv data from run1...
# Processing ERR2984773_GATBMiniaPipeline_phred.csv data from run1...
# Processing ENN_Unicycler_phred.csv data from run3...
# Processing ENN_MEGAHIT_phred.csv data from run3...
# Processing ENN_ABySS_phred.csv data from run3...
# Processing ENN_MINIA_phred.csv data from run3...
# Processing ENN_GATBMiniaPipeline_phred.csv data from run3...
# Processing ENN_BCALM2_phred.csv data from run3...
# Processing ENN_VelvetOptimiser_phred.csv data from run3...
# Processing ENN_metaSPAdes_phred.csv data from run3...
# Processing ENN_SPAdes_phred.csv data from run3...
# Processing ENN_MetaHipMer2_phred.csv data from run3...
# Processing ENN_IDBA-UD_phred.csv data from run3...
# Processing ENN_SKESA_phred.csv data from run3...
# Processing EMS_VelvetOptimiser_phred.csv data from run3...
# Processing EMS_SKESA_phred.csv data from run3...
# Processing EMS_IDBA-UD_phred.csv data from run3...
# Processing EMS_BCALM2_phred.csv data from run3...
# Processing EMS_Unicycler_phred.csv data from run3...
# Processing EMS_ABySS_phred.csv data from run3...
# Processing EMS_MINIA_phred.csv data from run3...
# Processing EMS_metaSPAdes_phred.csv data from run3...
# Processing EMS_MetaHipMer2_phred.csv data from run3...
# Processing EMS_SPAdes_phred.csv data from run3...
# Processing EMS_MEGAHIT_phred.csv data from run3...
# Processing EMS_GATBMiniaPipeline_phred.csv data from run3...
# Processing ERR2984773_SKESA_phred.csv data from run3...
# Processing ERR2984773_MetaHipMer2_phred.csv data from run3...
# Processing ERR2984773_Unicycler_phred.csv data from run3...
# Processing ERR2984773_BCALM2_phred.csv data from run3...
# Processing ERR2984773_VelvetOptimiser_phred.csv data from run3...
# Processing ERR2984773_SPAdes_phred.csv data from run3...
# Processing ERR2984773_IDBA-UD_phred.csv data from run3...
# Processing ERR2984773_metaSPAdes_phred.csv data from run3...
# Processing ERR2984773_MEGAHIT_phred.csv data from run3...
# Processing ERR2984773_MINIA_phred.csv data from run3...
# Processing ERR2984773_GATBMiniaPipeline_phred.csv data from run3...
# Processing ENN_Unicycler_phred.csv data from run2...
# Processing ENN_MEGAHIT_phred.csv data from run2...
# Processing ENN_ABySS_phred.csv data from run2...
# Processing ENN_MINIA_phred.csv data from run2...
# Processing ENN_GATBMiniaPipeline_phred.csv data from run2...
# Processing ENN_BCALM2_phred.csv data from run2...
# Processing ENN_VelvetOptimiser_phred.csv data from run2...
# Processing ENN_metaSPAdes_phred.csv data from run2...
# Processing ENN_SPAdes_phred.csv data from run2...
# Processing ENN_MetaHipMer2_phred.csv data from run2...
# Processing ENN_IDBA-UD_phred.csv data from run2...
# Processing ENN_SKESA_phred.csv data from run2...
# Processing EMS_VelvetOptimiser_phred.csv data from run2...
# Processing EMS_SKESA_phred.csv data from run2...
# Processing EMS_IDBA-UD_phred.csv data from run2...
# Processing EMS_BCALM2_phred.csv data from run2...
# Processing EMS_Unicycler_phred.csv data from run2...
# Processing EMS_ABySS_phred.csv data from run2...
# Processing EMS_MINIA_phred.csv data from run2...
# Processing EMS_metaSPAdes_phred.csv data from run2...
# Processing EMS_MetaHipMer2_phred.csv data from run2...
# Processing EMS_SPAdes_phred.csv data from run2...
# Processing EMS_MEGAHIT_phred.csv data from run2...
# Processing EMS_GATBMiniaPipeline_phred.csv data from run2...
# Processing ERR2984773_SKESA_phred.csv data from run2...
# Processing ERR2984773_MetaHipMer2_phred.csv data from run2...
# Processing ERR2984773_Unicycler_phred.csv data from run2...
# Processing ERR2984773_BCALM2_phred.csv data from run2...
# Processing ERR2984773_VelvetOptimiser_phred.csv data from run2...
# Processing ERR2984773_SPAdes_phred.csv data from run2...
# Processing ERR2984773_IDBA-UD_phred.csv data from run2...
# Processing ERR2984773_ABySS_phred.csv data from run2...
# Processing ERR2984773_metaSPAdes_phred.csv data from run2...
# Processing ERR2984773_MEGAHIT_phred.csv data from run2...
# Processing ERR2984773_MINIA_phred.csv data from run2...
# Processing ERR2984773_GATBMiniaPipeline_phred.csv data from run2...
#          run      Sample          Assembler                       Reference  \
# 0       run2         LNN              MINIA               Bacillus_subtilis
# 1       run2         LNN              MINIA               Bacillus_subtilis
# 2       run2         LNN              MINIA               Bacillus_subtilis
# 3       run2         LNN              MINIA               Bacillus_subtilis
# 4       run2         LNN              MINIA               Bacillus_subtilis
# ...      ...         ...                ...                             ...
# 204050  run2  ERR2984773  GATBMiniaPipeline           Staphylococcus_aureus
# 204051  run2  ERR2984773  GATBMiniaPipeline           Staphylococcus_aureus
# 204052  run2  ERR2984773  GATBMiniaPipeline  Staphylococcus_aureus_plasmid1
# 204053  run2  ERR2984773  GATBMiniaPipeline  Staphylococcus_aureus_plasmid2
# 204054  run2  ERR2984773  GATBMiniaPipeline  Staphylococcus_aureus_plasmid3
#
#        Contig Contig Length Phred Quality Score
# 0          14          1209  30.824263008607677
# 1         131         33942   39.28677437796009
# 2         198          1986                60.0
# 3         461          7500                60.0
# 4         499         56833                60.0
# ...       ...           ...                 ...
# 204050   5377         44765                  60
# 204051   5382        129676                  60
# 204052   1920          6515  23.367931653289368
# 204053    681          2369                  60
# 204054    573          3146                  60
#
# [204055 rows x 7 columns]

# %%
PLS_df.Reference.unique()
# Out:
# array(['Bacillus_subtilis', 'Lactobacillus_fermentum',
#        'Listeria_monocytogenes', 'Pseudomonas_aeruginosa',
#        'Salmonella_enterica', 'Escherichia_coli', 'Enterococcus_faecalis',
#        'Escherichia_coli_plasmid', 'Staphylococcus_aureus',
#        'Staphylococcus_aureus_plasmid1', 'Staphylococcus_aureus_plasmid2',
#        'Staphylococcus_aureus_plasmid3'], dtype=object)

# %%
PLS_df = PLS_df.drop_duplicates(subset=['Contig Length', 'Phred Quality Score'])

# %%
PLS_df
# Out:
#          run      Sample          Assembler                       Reference  \
# 0       run2         LNN              MINIA               Bacillus_subtilis
# 1       run2         LNN              MINIA               Bacillus_subtilis
# 2       run2         LNN              MINIA               Bacillus_subtilis
# 3       run2         LNN              MINIA               Bacillus_subtilis
# 4       run2         LNN              MINIA               Bacillus_subtilis
# ...      ...         ...                ...                             ...
# 204047  run2  ERR2984773  GATBMiniaPipeline           Staphylococcus_aureus
# 204048  run2  ERR2984773  GATBMiniaPipeline           Staphylococcus_aureus
# 204049  run2  ERR2984773  GATBMiniaPipeline           Staphylococcus_aureus
# 204051  run2  ERR2984773  GATBMiniaPipeline           Staphylococcus_aureus
# 204052  run2  ERR2984773  GATBMiniaPipeline  Staphylococcus_aureus_plasmid1
#
#        Contig Contig Length Phred Quality Score
# 0          14          1209  30.824263008607677
# 1         131         33942   39.28677437796009
# 2         198          1986                60.0
# 3         461          7500                60.0
# 4         499         56833                60.0
# ...       ...           ...                 ...
# 204047   5298        143138                  60
# 204048   5372         51929                  60
# 204049   5375         52131                  60
# 204051   5382        129676                  60
# 204052   1920          6515  23.367931653289368
#
# [31100 rows x 7 columns]

# %%
PLS_df[['Contig Length', 'Phred Quality Score']] = PLS_df[['Contig Length', 'Phred Quality Score']].apply(pd.to_numeric)

# %%
PLS_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31100 entries, 0 to 204052
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   run                  31100 non-null  object
#  1   Sample               31100 non-null  object
#  2   Assembler            31100 non-null  object
#  3   Reference            31100 non-null  object
#  4   Contig               31100 non-null  object
#  5   Contig Length        31100 non-null  int64
#  6   Phred Quality Score  31100 non-null  float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 1.9+ MB

# %%
COLOURS = ['#5876c8', '#58AEC8', '#009392', '#39B185', '#9CCB86', '#E9E29C', '#EEB479', '#E88471', '#CF597E', '#a54765', '#a42a2a', '#835221']

# %%
fig=make_subplots(rows=3, cols=4, subplot_titles=[x.replace('_', ' ') for x in sorted(PLS_df.Reference.unique(), key=lambda v: v.upper(), reverse=False)],
                 shared_yaxes=True, shared_xaxes=True, x_title="Contig size", y_title="Score")
row=1
col=1
showlegend = True if col == 1 and row == 1 else False
for reference in sorted(PLS_df.Reference.unique(), key=lambda v: v.upper(), reverse=False):
    i=0
    print(row, col)
    for assembler in sorted(PLS_df['Assembler'].unique(), key=lambda v: v.upper(), reverse=True):
        print('---' + assembler)
        showlegend=True if col==1 and row==1 else False

        fig.add_trace(go.Scatter(y=PLS_df['Phred Quality Score'][(PLS_df['Reference'] == reference) &
                                                                         (PLS_df['Assembler'] == assembler)],
                                          x=PLS_df['Contig Length'][(PLS_df['Reference'] == reference) &
                                                                     (PLS_df['Assembler'] == assembler)],
                                          opacity=0.6, mode='markers', showlegend=showlegend, name=assembler,
                                          marker_color=COLOURS[i]), 
                              row=row, col=col)
        i+=1
    if col == 4:
        col = 1
        row += 1
    else:
        col += 1

for i in fig['layout']['annotations']:
    i['font']['size'] = 12
fig.update_layout(legend=dict(
    orientation="h",
    y=-0.1,
    x=0
))

fig.update_layout(plot_bgcolor='rgb(255,255,255)', title="Pls Metric per reference replicon")
fig.update_xaxes(showline=True, linewidth=1, linecolor='#DCDCDC', gridcolor='#DCDCDC', rangemode='tozero')
fig.update_yaxes(showline=True, linewidth=1, linecolor='#DCDCDC', gridcolor='#DCDCDC', range=[0, 70])

fig.show()
plot(fig, filename='Plots/PLS/Fig 6 - PLS metric for all samples.html', auto_open=False)
# Out:
# 1 1
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# 1 2
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# 1 3
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# 1 4
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# 2 1
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# 2 2
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# 2 3
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# 2 4
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# 3 1
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# 3 2
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# 3 3
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
# 3 4
# ---VelvetOptimiser
# ---Unicycler
# ---SPAdes
# ---SKESA
# ---MINIA
# ---metaSPAdes
# ---MetaHipMer2
# ---MEGAHIT
# ---IDBA-UD
# ---GATBMiniaPipeline
# ---BCALM2
# ---ABySS
2218,3964,8706,2037,1242,4759,8134,2000,4722,5558,4317,3275,3359,10004,4533,1838,4396,2869,3563,4594,1416,5075,7273,4297,4184,3560,6155,2330,5007,3771,6196,5856,4393,2882,3442,4834,2753,3508,2584,6183,5579,3683,5210,2514,2601,2961,2503,2492,2171,4188,1300,6724,2498,1994,7999,7030,3155,3700,5961,2676,2876,3310,3273,2849,3248,2918,7967,9070,2628,5380,1066,1958,1532,2278,1433,5832,4670,7330,4703,5015,5570,4017,3710,9978,7702,4213,7317,1201,3363,3825,2385,4468,4264,6405,5593,2556,3427,3736,2501,5666,8182,2450,10367,12202,3067,2607,1507,2563,1052,4296,1573,2561,2968,4087,4292,5643,5150,4027,3192,2281,10670,3053,14476,8226,6376,4161,3601,3434,3456,6084,1580,3414,1909,4556,2110,2476,2483,2706,3973,2296,2206,1589,6732,2409,4006,9075,4207,2844,1868,2747,1140,5082,17566,2079,1396,6370,2535,3406,1546,4088,3404,2909,3693,4030,1715, ...
# 'Plots/PLS/Fig 6 - PLS metric for all samples.html'

# %%
COLOURS = ['#a6cee3', '#1f78b4', '#b2df8a', '#33a02c', '#fb9a99', '#e31a1c',
           '#fdbf6f', '#ff7f00', '#cab2d6', '#6a3d9a', '#ebdb75', '#b15928']

for reference in PLS_df.Reference.unique():
    fig_PLS = make_subplots(rows=3, cols=2, shared_xaxes=True, x_title="Contig size", 
                                shared_yaxes=True, y_title='PLS',
                                subplot_titles=('LNN', 'ENN', 'LHS', 'EMS', 'ERR2935805', 'ERR2984773'))
    row_coord = 1
    for sample in ['LNN', 'LHS', 'ERR2935805']:
        i=0
        for assembler in sorted(PLS_df['Assembler'].unique(), key=lambda v: v.upper()):
            fig_PLS.add_trace(go.Scatter(y=PLS_df['Phred Quality Score'][(PLS_df['Reference'] == reference) &
                                                                         (PLS_df['Assembler'] == assembler) &
                                                                         (PLS_df['Sample'] == sample)],
                                          x=PLS_df['Contig Length'][(PLS_df['Reference'] == reference) &
                                                                     (PLS_df['Assembler'] == assembler) &
                                                                     (PLS_df['Sample'] == sample)],
                                          opacity=0.6, mode='markers', showlegend=False, name=assembler,
                                          marker_color=COLOURS[i]), 
                              row=row_coord, col=1)
            i +=1
        row_coord += 1

    row_coord = 1
    for sample in ['ENN', 'EMS', 'ERR2984773']:
        i=0
        showlegend = True if (row_coord == 1) else False
        for assembler in sorted(PLS_df['Assembler'].unique(), key=lambda v: v.upper()):
            fig_PLS.add_trace(go.Scatter(y=PLS_df['Phred Quality Score'][(PLS_df['Reference'] == reference) &
                                                                         (PLS_df['Assembler'] == assembler) &
                                                                         (PLS_df['Sample'] == sample)],
                                           x=PLS_df['Contig Length'][(PLS_df['Reference'] == reference) &
                                                                     (PLS_df['Assembler'] == assembler) &
                                                                     (PLS_df['Sample'] == sample)],
                                           opacity=0.6, mode='markers', showlegend=showlegend, name=assembler,
                                        marker_color=COLOURS[i]), 
                              row=row_coord, col=2)
            i += 1
        row_coord += 1


    fig_PLS.update_layout(plot_bgcolor='rgb(255,255,255)', title_text="PLS Metrics for {}".format(reference.replace('_', ' ')))
    # grid
"yaxis":"y"},{"marker":{"color":"#e31a1c"},"mode":"markers","name":"MetaHipMer2","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#fdbf6f"},"mode":"markers","name":"metaSPAdes","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#ff7f00"},"mode":"markers","name":"MINIA","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#cab2d6"},"mode":"markers","name":"SKESA","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#6a3d9a"},"mode":"markers","name":"SPAdes","opacity":0.6,"showlegend":false,"type":"scatter","x":[1194,1114,1094,1043,1023],"xaxis":"x","y":[8.951607388485774,15.417352125178043,60.0,60.0,13.866263433142601],"yaxis":"y"},{"marker":{"color":"#ebdb75"},"mode":"markers","name":"Unicycler","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#b15928"},"mode":"markers","name":"VelvetOptimiser","opacity":0.6,"showlegend":false,"type":"scatter","x":[1287,1421,1102,3381,1090,1420,1482,1039,2025,1177,1260,1188,1023,1220,3347,1149,1322,1590,1255,1390,1256,1022,1200,1144,1364,1408],"xaxis":"x","y":[10.376965395982618,6.185679718713348,12.292682378729104,4.675926916785755,6.174707494508658,15.188198888034707,6.966319395670543,5.542175496582214,8.655159454854697,4.85315733334934,10.629440471769392,7.825603692886987,6.674529528899538,13.961637506462353,7.523340056348576,14.268515731086982,11.481036015499225,9.43718549451267,12.12153000644575,5.655230004168699,7.02790292305441,8.333596367430125,5.157001606532141,5.39912084579118,9.334172460000088,2.9979795375428964],"yaxis":"y"},{"marker":{"color":"#a6cee3"},"mode":"markers","name":"ABySS","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#1f78b4"},"mode":"markers","name":"BCALM2","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#b2df8a"},"mode":"markers","name":"GATBMiniaPipeline","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#33a02c"},"mode":"markers","name":"IDBA-UD","opacity":0.6,"showlegend":false,"type":"scatter","x":[1261],"xaxis":"x3","y":[26.235938318534213],"yaxis":"y3"},{"marker":{"color":"#fb9a99"},"mode":"markers","name":"MEGAHIT","opacity":0.6,"showle ...
# <div>                            <div id="e15290c5-5f08-4345-84a2-7b5ee54957c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e15290c5-5f08-4345-84a2-7b5ee54957c4")) {                    Plotly.newPlot(                        "e15290c5-5f08-4345-84a2-7b5ee54957c4",                        [{"marker":{"color":"#a6cee3"},"mode":"markers","name":"ABySS","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#1f78b4"},"mode":"markers","name":"BCALM2","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#b2df8a"},"mode":"markers","name":"GATBMiniaPipeline","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#33a02c"},"mode":"markers","name":"IDBA-UD","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#fb9a99"},"mode":"markers","name":"MEGAHIT","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#e31a1c"},"mode":"markers","name":"MetaHipMer2","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#fdbf6f"},"mode":"markers","name":"metaSPAdes","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#ff7f00"},"mode":"markers","name":"MINIA","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#cab2d6"},"mode":"markers","name":"SKESA","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#6a3d9a"},"mode":"markers","name":"SPAdes","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#ebdb75"},"mode":"markers","name":"Unicycler","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#b15928"},"mode":"markers","name":"VelvetOptimiser","opacity":0.6,"showlegend":false,"type":"scatter","x":[4071],"xaxis":"x","y":[60.0],"yaxis":"y"},{"marker":{"color":"#a6cee3"},"mode":"markers","name":"ABySS","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#1f78b4"},"mode":"markers","name":"BCALM2","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#b2df8a"},"mode":"markers","name":"GATBMiniaPipeline","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#33a02c"},"mode":"markers","name":"IDBA-UD","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#fb9a99"},"mode":"markers","name":"MEGAHIT","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#e31a1c"},"mode":"markers","name":"MetaHipMer2","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#fdbf6f"},"mode":"markers","name":"metaSPAdes","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#ff7f00"},"mode":"markers","name":"MINIA","opacity":0.6,"showlegend":false,"type":"scatter","x":[4308,5590,2071,5590],"xaxis":"x3","y":[60.0,60.0,60.0,60.0],"yaxis":"y3"},{"marker":{"color":"#cab2d6"},"mode":"markers","name":"SKESA","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#6a3d9a"},"mode":"markers","name":"SPAdes","opacity":0.6,"showlegend":false,"type":"scatter","x":[3287,2698,2413,2248,2112,1552],"xaxis":"x3"," ...
# <div>                            <div id="975883a3-1b67-4769-bb59-30d50e504524" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("975883a3-1b67-4769-bb59-30d50e504524")) {                    Plotly.newPlot(                        "975883a3-1b67-4769-bb59-30d50e504524",                        [{"marker":{"color":"#a6cee3"},"mode":"markers","name":"ABySS","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#1f78b4"},"mode":"markers","name":"BCALM2","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#b2df8a"},"mode":"markers","name":"GATBMiniaPipeline","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#33a02c"},"mode":"markers","name":"IDBA-UD","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#fb9a99"},"mode":"markers","name":"MEGAHIT","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#e31a1c"},"mode":"markers","name":"MetaHipMer2","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#fdbf6f"},"mode":"markers","name":"metaSPAdes","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#ff7f00"},"mode":"markers","name":"MINIA","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#cab2d6"},"mode":"markers","name":"SKESA","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#6a3d9a"},"mode":"markers","name":"SPAdes","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#ebdb75"},"mode":"markers","name":"Unicycler","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#b15928"},"mode":"markers","name":"VelvetOptimiser","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#a6cee3"},"mode":"markers","name":"ABySS","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#1f78b4"},"mode":"markers","name":"BCALM2","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#b2df8a"},"mode":"markers","name":"GATBMiniaPipeline","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#33a02c"},"mode":"markers","name":"IDBA-UD","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#fb9a99"},"mode":"markers","name":"MEGAHIT","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#e31a1c"},"mode":"markers","name":"MetaHipMer2","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#fdbf6f"},"mode":"markers","name":"metaSPAdes","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#ff7f00"},"mode":"markers","name":"MINIA","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#cab2d6"},"mode":"markers","name":"SKESA","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#6a3d9a"},"mode":"markers","name":"SPAdes","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#ebdb75"},"mode":"markers","name":" ...
# <div>                            <div id="658d7ae7-0fe3-4644-a653-c8d859767705" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("658d7ae7-0fe3-4644-a653-c8d859767705")) {                    Plotly.newPlot(                        "658d7ae7-0fe3-4644-a653-c8d859767705",                        [{"marker":{"color":"#a6cee3"},"mode":"markers","name":"ABySS","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#1f78b4"},"mode":"markers","name":"BCALM2","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#b2df8a"},"mode":"markers","name":"GATBMiniaPipeline","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#33a02c"},"mode":"markers","name":"IDBA-UD","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#fb9a99"},"mode":"markers","name":"MEGAHIT","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#e31a1c"},"mode":"markers","name":"MetaHipMer2","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#fdbf6f"},"mode":"markers","name":"metaSPAdes","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#ff7f00"},"mode":"markers","name":"MINIA","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#cab2d6"},"mode":"markers","name":"SKESA","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#6a3d9a"},"mode":"markers","name":"SPAdes","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#ebdb75"},"mode":"markers","name":"Unicycler","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#b15928"},"mode":"markers","name":"VelvetOptimiser","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#a6cee3"},"mode":"markers","name":"ABySS","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#1f78b4"},"mode":"markers","name":"BCALM2","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#b2df8a"},"mode":"markers","name":"GATBMiniaPipeline","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#33a02c"},"mode":"markers","name":"IDBA-UD","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#fb9a99"},"mode":"markers","name":"MEGAHIT","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#e31a1c"},"mode":"markers","name":"MetaHipMer2","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#fdbf6f"},"mode":"markers","name":"metaSPAdes","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#ff7f00"},"mode":"markers","name":"MINIA","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#cab2d6"},"mode":"markers","name":"SKESA","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#6a3d9a"},"mode":"markers","name":"SPAdes","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#ebdb75"},"mode":"markers","name":" ...
# <div>                            <div id="b1e795ad-87a9-4090-baa3-5b2e0a5f6a01" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b1e795ad-87a9-4090-baa3-5b2e0a5f6a01")) {                    Plotly.newPlot(                        "b1e795ad-87a9-4090-baa3-5b2e0a5f6a01",                        [{"marker":{"color":"#a6cee3"},"mode":"markers","name":"ABySS","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#1f78b4"},"mode":"markers","name":"BCALM2","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#b2df8a"},"mode":"markers","name":"GATBMiniaPipeline","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#33a02c"},"mode":"markers","name":"IDBA-UD","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#fb9a99"},"mode":"markers","name":"MEGAHIT","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#e31a1c"},"mode":"markers","name":"MetaHipMer2","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#fdbf6f"},"mode":"markers","name":"metaSPAdes","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#ff7f00"},"mode":"markers","name":"MINIA","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#cab2d6"},"mode":"markers","name":"SKESA","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#6a3d9a"},"mode":"markers","name":"SPAdes","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#ebdb75"},"mode":"markers","name":"Unicycler","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#b15928"},"mode":"markers","name":"VelvetOptimiser","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#a6cee3"},"mode":"markers","name":"ABySS","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#1f78b4"},"mode":"markers","name":"BCALM2","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#b2df8a"},"mode":"markers","name":"GATBMiniaPipeline","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#33a02c"},"mode":"markers","name":"IDBA-UD","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#fb9a99"},"mode":"markers","name":"MEGAHIT","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#e31a1c"},"mode":"markers","name":"MetaHipMer2","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#fdbf6f"},"mode":"markers","name":"metaSPAdes","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#ff7f00"},"mode":"markers","name":"MINIA","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#cab2d6"},"mode":"markers","name":"SKESA","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#6a3d9a"},"mode":"markers","name":"SPAdes","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#ebdb75"},"mode":"markers","name":" ...
# <div>                            <div id="cd8519d6-8481-4ed9-ad17-8ddacc0bdfe7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cd8519d6-8481-4ed9-ad17-8ddacc0bdfe7")) {                    Plotly.newPlot(                        "cd8519d6-8481-4ed9-ad17-8ddacc0bdfe7",                        [{"marker":{"color":"#a6cee3"},"mode":"markers","name":"ABySS","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#1f78b4"},"mode":"markers","name":"BCALM2","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#b2df8a"},"mode":"markers","name":"GATBMiniaPipeline","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#33a02c"},"mode":"markers","name":"IDBA-UD","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#fb9a99"},"mode":"markers","name":"MEGAHIT","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#e31a1c"},"mode":"markers","name":"MetaHipMer2","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#fdbf6f"},"mode":"markers","name":"metaSPAdes","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#ff7f00"},"mode":"markers","name":"MINIA","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#cab2d6"},"mode":"markers","name":"SKESA","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#6a3d9a"},"mode":"markers","name":"SPAdes","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#ebdb75"},"mode":"markers","name":"Unicycler","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#b15928"},"mode":"markers","name":"VelvetOptimiser","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#a6cee3"},"mode":"markers","name":"ABySS","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#1f78b4"},"mode":"markers","name":"BCALM2","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#b2df8a"},"mode":"markers","name":"GATBMiniaPipeline","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#33a02c"},"mode":"markers","name":"IDBA-UD","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#fb9a99"},"mode":"markers","name":"MEGAHIT","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#e31a1c"},"mode":"markers","name":"MetaHipMer2","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#fdbf6f"},"mode":"markers","name":"metaSPAdes","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#ff7f00"},"mode":"markers","name":"MINIA","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#cab2d6"},"mode":"markers","name":"SKESA","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#6a3d9a"},"mode":"markers","name":"SPAdes","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#ebdb75"},"mode":"markers","name":" ...
# <div>                            <div id="e643052a-cbb2-4297-860a-18d3e714fca9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e643052a-cbb2-4297-860a-18d3e714fca9")) {                    Plotly.newPlot(                        "e643052a-cbb2-4297-860a-18d3e714fca9",                        [{"marker":{"color":"#a6cee3"},"mode":"markers","name":"ABySS","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#1f78b4"},"mode":"markers","name":"BCALM2","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#b2df8a"},"mode":"markers","name":"GATBMiniaPipeline","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#33a02c"},"mode":"markers","name":"IDBA-UD","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#fb9a99"},"mode":"markers","name":"MEGAHIT","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#e31a1c"},"mode":"markers","name":"MetaHipMer2","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#fdbf6f"},"mode":"markers","name":"metaSPAdes","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#ff7f00"},"mode":"markers","name":"MINIA","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#cab2d6"},"mode":"markers","name":"SKESA","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#6a3d9a"},"mode":"markers","name":"SPAdes","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#ebdb75"},"mode":"markers","name":"Unicycler","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#b15928"},"mode":"markers","name":"VelvetOptimiser","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x","y":[],"yaxis":"y"},{"marker":{"color":"#a6cee3"},"mode":"markers","name":"ABySS","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#1f78b4"},"mode":"markers","name":"BCALM2","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#b2df8a"},"mode":"markers","name":"GATBMiniaPipeline","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#33a02c"},"mode":"markers","name":"IDBA-UD","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#fb9a99"},"mode":"markers","name":"MEGAHIT","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#e31a1c"},"mode":"markers","name":"MetaHipMer2","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#fdbf6f"},"mode":"markers","name":"metaSPAdes","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#ff7f00"},"mode":"markers","name":"MINIA","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#cab2d6"},"mode":"markers","name":"SKESA","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#6a3d9a"},"mode":"markers","name":"SPAdes","opacity":0.6,"showlegend":false,"type":"scatter","x":[],"xaxis":"x3","y":[],"yaxis":"y3"},{"marker":{"color":"#ebdb75"},"mode":"markers","name":" ...
